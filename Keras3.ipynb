# %%
# !pip install tensorflow

# %%
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# Load breast cancer dataset
data = datasets.load_breast_cancer()
X, y = data.data, data.target

# Preprocess the data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Convert labels to categorical one-hot encoding
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Define a simple neural network with dropout
model = Sequential([
    Dense(128, activation='relu', input_dim=X_train.shape[1]),
    Dropout(0.5),
    Dense(2, activation='softmax')
])

# Compile the model
optimizer = Adam()
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=0)

# Evaluate the model
score = model.evaluate(X_test, y_test, verbose=0)
accuracy = score[1]

# Print the accuracy
print("Accuracy with dropout regularization: {:.2f}%".format(accuracy * 100))

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn import datasets
from sklearn.model_selection import train_test_split

# Load the breast cancer dataset
cancer = datasets.load_breast_cancer()
X = cancer.data
y = cancer.target

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y)

# Create a sequential model
model = Sequential()

# Add a dense layer with 100 units and ReLU activation
model.add(Dense(100, activation='relu', input_shape=(30,)))

# Add a dropout layer with a rate of 0.5
model.add(Dropout(0.5))

# Add a dense output layer with 2 units and softmax activation
model.add(Dense(2, activation='softmax'))

# Compile the model with categorical cross-entropy loss and the Adam optimizer
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model for 100 epochs
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test))

# Evaluate the model on the test set
score = model.evaluate(X_test, y_test)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 19ms/step - loss: 51.2940 - accuracy: 0.4390 - val_loss: 24.5527 - val_accuracy: 0.3566
# Epoch 2/100
# 14/14 [==============================] - 0s 5ms/step - loss: 37.2824 - accuracy: 0.4202 - val_loss: 6.7005 - val_accuracy: 0.3566
# Epoch 3/100
# 14/14 [==============================] - 0s 5ms/step - loss: 27.3232 - accuracy: 0.4953 - val_loss: 3.0919 - val_accuracy: 0.4755
# Epoch 4/100
# 14/14 [==============================] - 0s 5ms/step - loss: 19.7487 - accuracy: 0.5258 - val_loss: 1.6222 - val_accuracy: 0.7063
# Epoch 5/100
# 14/14 [==============================] - 0s 5ms/step - loss: 15.0058 - accuracy: 0.5399 - val_loss: 1.4782 - val_accuracy: 0.7343
# Epoch 6/100
# 14/14 [==============================] - 0s 5ms/step - loss: 10.7130 - accuracy: 0.6174 - val_loss: 0.7046 - val_accuracy: 0.8951
# Epoch 7/100
# 14/14 [==============================] - 0s 5ms/step - loss: 8.5188 - accuracy: 0.6056 - val_loss: 0.9466 - val_accuracy: 0.8462
# Epoch 8/100
# 14/14 [==============================] - 0s 5ms/step - loss: 5.5316 - accuracy: 0.7089 - val_loss: 0.8400 - val_accuracy: 0.9021
# Epoch 9/100
# 14/14 [==============================] - 0s 6ms/step - loss: 3.9156 - accuracy: 0.7441 - val_loss: 0.9185 - val_accuracy: 0.8951
# Epoch 10/100
# 14/14 [==============================] - 0s 6ms/step - loss: 2.9551 - accuracy: 0.7676 - val_loss: 0.8725 - val_accuracy: 0.9091
# Epoch 11/100
# 14/14 [==============================] - 0s 5ms/step - loss: 1.7750 - accuracy: 0.8286 - val_loss: 1.1167 - val_accuracy: 0.9021
# Epoch 12/100
# 14/14 [==============================] - 0s 6ms/step - loss: 1.6378 - accuracy: 0.8451 - val_loss: 0.8582 - val_accuracy: 0.8951
# Epoch 13/100
# 14/14 [==============================] - 0s 5ms/step - loss: 1.2471 - accuracy: 0.8521 - val_loss: 0.8741 - val_accuracy: 0.8951
# Epoch 14/100
# 14/14 [==============================] - 0s 5ms/step - loss: 1.0292 - accuracy: 0.8685 - val_loss: 0.9376 - val_accuracy: 0.8951
# Epoch 15/100
# 14/14 [==============================] - 0s 5ms/step - loss: 1.3547 - accuracy: 0.8521 - val_loss: 0.7925 - val_accuracy: 0.9021
# Epoch 16/100
# 14/14 [==============================] - 0s 5ms/step - loss: 1.1210 - accuracy: 0.8310 - val_loss: 0.6997 - val_accuracy: 0.9021
# Epoch 17/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.7717 - accuracy: 0.8568 - val_loss: 0.6233 - val_accuracy: 0.9021
# Epoch 18/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.5207 - accuracy: 0.8592 - val_loss: 0.5960 - val_accuracy: 0.9021
# Epoch 19/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6948 - accuracy: 0.8873 - val_loss: 0.4932 - val_accuracy: 0.9021
# Epoch 20/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4902 - accuracy: 0.8709 - val_loss: 0.4805 - val_accuracy: 0.9021
# Epoch 21/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.4570 - accuracy: 0.8944 - val_loss: 0.4589 - val_accuracy: 0.9021
# Epoch 22/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3712 - accuracy: 0.8920 - val_loss: 0.4386 - val_accuracy: 0.9021
# Epoch 23/100
# 14/14 [==============================] - 0s 7ms/step - loss: 0.3947 - accuracy: 0.8850 - val_loss: 0.4118 - val_accuracy: 0.9021
# Epoch 24/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3574 - accuracy: 0.8826 - val_loss: 0.3779 - val_accuracy: 0.9021
# Epoch 25/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3276 - accuracy: 0.8944 - val_loss: 0.3870 - val_accuracy: 0.8951
# Epoch 26/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2668 - accuracy: 0.9155 - val_loss: 0.3768 - val_accuracy: 0.9091
# Epoch 27/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2429 - accuracy: 0.9038 - val_loss: 0.3829 - val_accuracy: 0.8951
# Epoch 28/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2655 - accuracy: 0.9131 - val_loss: 0.3958 - val_accuracy: 0.9021
# Epoch 29/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3075 - accuracy: 0.9061 - val_loss: 0.3685 - val_accuracy: 0.9021
# Epoch 30/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2423 - accuracy: 0.9319 - val_loss: 0.4127 - val_accuracy: 0.9021
# Epoch 31/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2491 - accuracy: 0.9178 - val_loss: 0.3750 - val_accuracy: 0.9021
# Epoch 32/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2506 - accuracy: 0.9249 - val_loss: 0.4058 - val_accuracy: 0.8951
# Epoch 33/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2453 - accuracy: 0.9085 - val_loss: 0.4507 - val_accuracy: 0.9021
# Epoch 34/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2313 - accuracy: 0.9296 - val_loss: 0.3575 - val_accuracy: 0.8951
# Epoch 35/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2686 - accuracy: 0.9085 - val_loss: 0.3487 - val_accuracy: 0.8951
# Epoch 36/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2754 - accuracy: 0.9038 - val_loss: 0.3874 - val_accuracy: 0.9021
# Epoch 37/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2188 - accuracy: 0.9225 - val_loss: 0.3747 - val_accuracy: 0.9021
# Epoch 38/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2346 - accuracy: 0.9131 - val_loss: 0.3758 - val_accuracy: 0.9021
# Epoch 39/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2469 - accuracy: 0.9225 - val_loss: 0.3608 - val_accuracy: 0.8951
# Epoch 40/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2132 - accuracy: 0.9202 - val_loss: 0.3537 - val_accuracy: 0.8951
# Epoch 41/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2507 - accuracy: 0.9202 - val_loss: 0.3386 - val_accuracy: 0.8951
# Epoch 42/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1931 - accuracy: 0.9343 - val_loss: 0.3552 - val_accuracy: 0.8951
# Epoch 43/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2027 - accuracy: 0.9272 - val_loss: 0.3418 - val_accuracy: 0.8951
# Epoch 44/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2218 - accuracy: 0.9202 - val_loss: 0.3417 - val_accuracy: 0.8951
# Epoch 45/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2132 - accuracy: 0.9272 - val_loss: 0.3432 - val_accuracy: 0.8951
# Epoch 46/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2203 - accuracy: 0.9319 - val_loss: 0.3364 - val_accuracy: 0.8951
# Epoch 47/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1904 - accuracy: 0.9296 - val_loss: 0.3551 - val_accuracy: 0.8951
# Epoch 48/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1895 - accuracy: 0.9343 - val_loss: 0.3644 - val_accuracy: 0.8951
# Epoch 49/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2212 - accuracy: 0.9249 - val_loss: 0.3637 - val_accuracy: 0.8951
# Epoch 50/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1866 - accuracy: 0.9343 - val_loss: 0.3239 - val_accuracy: 0.8951
# Epoch 51/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2116 - accuracy: 0.9319 - val_loss: 0.3327 - val_accuracy: 0.8951
# Epoch 52/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2077 - accuracy: 0.9296 - val_loss: 0.3484 - val_accuracy: 0.8881
# Epoch 53/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2102 - accuracy: 0.9225 - val_loss: 0.3237 - val_accuracy: 0.8881
# Epoch 54/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2095 - accuracy: 0.9225 - val_loss: 0.3232 - val_accuracy: 0.8881
# Epoch 55/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2145 - accuracy: 0.9178 - val_loss: 0.3289 - val_accuracy: 0.9021
# Epoch 56/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2151 - accuracy: 0.9296 - val_loss: 0.3280 - val_accuracy: 0.9021
# Epoch 57/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2082 - accuracy: 0.9178 - val_loss: 0.3419 - val_accuracy: 0.9021
# Epoch 58/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2176 - accuracy: 0.9202 - val_loss: 0.3284 - val_accuracy: 0.8951
# Epoch 59/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2827 - accuracy: 0.9038 - val_loss: 0.3175 - val_accuracy: 0.8951
# Epoch 60/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2237 - accuracy: 0.9178 - val_loss: 0.3373 - val_accuracy: 0.8951
# Epoch 61/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2096 - accuracy: 0.9202 - val_loss: 0.3413 - val_accuracy: 0.9021
# Epoch 62/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2076 - accuracy: 0.9272 - val_loss: 0.3247 - val_accuracy: 0.9021
# Epoch 63/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2062 - accuracy: 0.9319 - val_loss: 0.3286 - val_accuracy: 0.9021
# Epoch 64/100
# 14/14 [==============================] - 0s 6ms/step - loss: 0.2300 - accuracy: 0.9131 - val_loss: 0.3288 - val_accuracy: 0.9021
# Epoch 65/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2157 - accuracy: 0.9272 - val_loss: 0.3298 - val_accuracy: 0.9021
# Epoch 66/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2119 - accuracy: 0.9225 - val_loss: 0.3283 - val_accuracy: 0.8951
# Epoch 67/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2094 - accuracy: 0.9366 - val_loss: 0.3460 - val_accuracy: 0.8951
# Epoch 68/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1967 - accuracy: 0.9272 - val_loss: 0.3569 - val_accuracy: 0.8881
# Epoch 69/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2057 - accuracy: 0.9272 - val_loss: 0.3689 - val_accuracy: 0.8951
# Epoch 70/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2078 - accuracy: 0.9296 - val_loss: 0.3406 - val_accuracy: 0.8951
# Epoch 71/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1954 - accuracy: 0.9272 - val_loss: 0.4115 - val_accuracy: 0.8881
# Epoch 72/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1991 - accuracy: 0.9343 - val_loss: 0.3157 - val_accuracy: 0.8951
# Epoch 73/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2063 - accuracy: 0.9155 - val_loss: 0.3439 - val_accuracy: 0.9021
# Epoch 74/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1974 - accuracy: 0.9249 - val_loss: 0.3424 - val_accuracy: 0.9021
# Epoch 75/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1895 - accuracy: 0.9437 - val_loss: 0.3255 - val_accuracy: 0.9021
# Epoch 76/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2006 - accuracy: 0.9272 - val_loss: 0.3291 - val_accuracy: 0.9021
# Epoch 77/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2184 - accuracy: 0.9178 - val_loss: 0.3485 - val_accuracy: 0.8951
# Epoch 78/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2012 - accuracy: 0.9155 - val_loss: 0.3362 - val_accuracy: 0.8951
# Epoch 79/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2153 - accuracy: 0.9319 - val_loss: 0.3326 - val_accuracy: 0.8951
# Epoch 80/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2422 - accuracy: 0.9249 - val_loss: 0.3578 - val_accuracy: 0.8951
# Epoch 81/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1922 - accuracy: 0.9272 - val_loss: 0.3110 - val_accuracy: 0.9091
# Epoch 82/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2040 - accuracy: 0.9272 - val_loss: 0.3156 - val_accuracy: 0.8951
# Epoch 83/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1846 - accuracy: 0.9343 - val_loss: 0.3140 - val_accuracy: 0.8951
# Epoch 84/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2085 - accuracy: 0.9272 - val_loss: 0.3480 - val_accuracy: 0.9021
# Epoch 85/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2114 - accuracy: 0.9296 - val_loss: 0.3544 - val_accuracy: 0.9021
# Epoch 86/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1882 - accuracy: 0.9319 - val_loss: 0.3204 - val_accuracy: 0.8951
# Epoch 87/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1886 - accuracy: 0.9272 - val_loss: 0.4213 - val_accuracy: 0.8811
# Epoch 88/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2444 - accuracy: 0.9202 - val_loss: 0.3343 - val_accuracy: 0.8811
# Epoch 89/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2086 - accuracy: 0.9272 - val_loss: 0.3314 - val_accuracy: 0.8951
# Epoch 90/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2439 - accuracy: 0.9131 - val_loss: 0.3096 - val_accuracy: 0.8951
# Epoch 91/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1910 - accuracy: 0.9296 - val_loss: 0.3303 - val_accuracy: 0.8881
# Epoch 92/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2144 - accuracy: 0.9225 - val_loss: 0.3320 - val_accuracy: 0.9021
# Epoch 93/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1841 - accuracy: 0.9343 - val_loss: 0.3315 - val_accuracy: 0.9021
# Epoch 94/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1932 - accuracy: 0.9413 - val_loss: 0.3583 - val_accuracy: 0.9091
# Epoch 95/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2299 - accuracy: 0.9249 - val_loss: 0.3518 - val_accuracy: 0.9021
# Epoch 96/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2024 - accuracy: 0.9343 - val_loss: 0.3610 - val_accuracy: 0.9021
# Epoch 97/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1959 - accuracy: 0.9249 - val_loss: 0.3278 - val_accuracy: 0.9021
# Epoch 98/100
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1832 - accuracy: 0.9343 - val_loss: 0.3399 - val_accuracy: 0.8951
# Epoch 99/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1933 - accuracy: 0.9319 - val_loss: 0.3510 - val_accuracy: 0.8951
# Epoch 100/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1943 - accuracy: 0.9272 - val_loss: 0.3311 - val_accuracy: 0.8881
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3311 - accuracy: 0.8881
# Test loss: 0.3310886323451996
# Test accuracy: 0.8881118893623352
